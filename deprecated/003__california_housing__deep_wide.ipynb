# %%
from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow import keras
import os

# %% [markdown]
# ### Tensorboard
# #### Create a log dir and a log file for the current running instance
# #### Tensorboard callback for visualization

# %%
root_logdir = os.path.join(os.curdir, "my_logs")

def get_run_logdir():
    import time
    run_id = time.strftime("california_housing__deep_wide_%Y_%m_%d-%H_%M_%S")
    return os.path.join(root_logdir, run_id)

# Do it dynamically while fitting
# run_logdir = get_run_logdir()
# tensorboard_cb = keras.callbacks.TensorBoard(run_logdir)

# %%
housing = fetch_california_housing()
X_train, X_test, y_train, y_test = train_test_split(housing.data, housing.target)

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# ###  Passing the features through deep and wide channels
# #### This allows the neural network to learn both deep patterns (using deep path) and simple rules (through the short path)
# #### In contrast, a regular MLP forces all the data to flow through the full stack of layers; thus, simple patterns in the data may end up being distorted by this sequence of transformations

# %%
input_ = keras.layers.Input(shape=X_train.shape[1:])
hidden = keras.layers.Dense(30, activation="relu")(input_)
hidden = keras.layers.Dense(30, activation="relu")(hidden)
concat = keras.layers.Concatenate()([input_, hidden])
output = keras.layers.Dense(1)(concat)
model = keras.Model(inputs=[input_], outputs=[output])

model.compile(loss="mean_squared_error", optimizer="sgd")
model.summary()

history = model.fit(X_train, y_train, epochs=20, validation_split=0.2, callbacks=[keras.callbacks.TensorBoard(get_run_logdir())])

mse_test = model.evaluate(X_test, y_test)

X_new = X_test[:3] #pretend these are new instances to do some testing
y_pred = model.predict(X_new)
print(y_test[:3], y_pred)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 8)]          0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 30)           270         input_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 30)           930         dense[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 38)           0           input_1[0][0]
#                                                                  dense_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 1)            39          concatenate[0][0]
# ==================================================================================================
# Total params: 1,239
# Trainable params: 1,239
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Train on 12384 samples, validate on 3096 samples
# Epoch 1/20
# 12384/12384 [==============================] - 1s 41us/sample - loss: 1.6404 - val_loss: 0.7708
# Epoch 2/20
# 12384/12384 [==============================] - 0s 28us/sample - loss: 0.6965 - val_loss: 0.6961
# Epoch 3/20
# 12384/12384 [==============================] - 0s 30us/sample - loss: 0.6361 - val_loss: 0.6470
# Epoch 4/20
# 12384/12384 [==============================] - 0s 26us/sample - loss: 0.5933 - val_loss: 0.6126
# Epoch 5/20
# 12384/12384 [==============================] - 0s 25us/sample - loss: 0.5614 - val_loss: 0.5829
# Epoch 6/20
# 12384/12384 [==============================] - 0s 25us/sample - loss: 0.5381 - val_loss: 0.5620
# Epoch 7/20
# 12384/12384 [==============================] - 0s 26us/sample - loss: 0.5181 - val_loss: 0.5413
# Epoch 8/20
# 12384/12384 [==============================] - 0s 27us/sample - loss: 0.5042 - val_loss: 0.5321
# Epoch 9/20
# 12384/12384 [==============================] - 0s 27us/sample - loss: 0.4902 - val_loss: 0.5177
# Epoch 10/20
# 12384/12384 [==============================] - 0s 30us/sample - loss: 0.4803 - val_loss: 0.5073
# Epoch 11/20
# 12384/12384 [==============================] - 0s 24us/sample - loss: 0.4712 - val_loss: 0.4990
# Epoch 12/20
# 12384/12384 [==============================] - 0s 29us/sample - loss: 0.4644 - val_loss: 0.4909
# Epoch 13/20
# 12384/12384 [==============================] - 0s 25us/sample - loss: 0.4561 - val_loss: 0.4849
# Epoch 14/20
# 12384/12384 [==============================] - 0s 25us/sample - loss: 0.4502 - val_loss: 0.4792
# Epoch 15/20
# 12384/12384 [==============================] - 0s 25us/sample - loss: 0.4451 - val_loss: 0.4747
# Epoch 16/20
# 12384/12384 [==============================] - 0s 28us/sample - loss: 0.4394 - val_loss: 0.4696
# Epoch 17/20
# 12384/12384 [==============================] - 0s 27us/sample - loss: 0.4346 - val_loss: 0.4687
# Epoch 18/20
# 12384/12384 [==============================] - 0s 27us/sample - loss: 0.4297 - val_loss: 0.4607
# Epoch 19/20
# 12384/12384 [==============================] - 0s 27us/sample - loss: 0.4259 - val_loss: 0.4555
# Epoch 20/20
# 12384/12384 [==============================] - 0s 25us/sample - loss: 0.4241 - val_loss: 0.4534
# 5160/5160 [==============================] - 0s 13us/sample - loss: 0.4403
# [4.259 2.563 2.595] [[2.7631702]
#  [2.8737574]
#  [2.6682458]]

# %% [markdown]
# ### Handling multiple inputs - one set of features through the deep channel and the other through wide channel (possibly overlapping set of features)

# %%
input_A = keras.layers.Input(shape=[5], name="wide_input")
input_B = keras.layers.Input(shape=[6], name="deep_input")
hidden = keras.layers.Dense(30, activation="relu")(input_B)
hidden = keras.layers.Dense(30, activation="relu")(hidden)
concat = keras.layers.Concatenate()([input_A, hidden])
output = keras.layers.Dense(1)(concat)
model = keras.Model(inputs=[input_A, input_B], outputs=[output])

model.compile(loss="mean_squared_error", optimizer="sgd")
model.summary()

history = model.fit((X_train[:, :5], X_train[:, 2:]), y_train, epochs=20, validation_split=0.2, 
                    callbacks=[keras.callbacks.TensorBoard(get_run_logdir())])

mse_test = model.evaluate((X_test[:, :5], X_test[:, 2:]), y_test)

X_new = X_test[:3] #pretend these are new instances to do some testing
y_pred = model.predict((X_new[:, :5], X_new[:, 2:]))
print(y_test[:3], y_pred)
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# deep_input (InputLayer)         [(None, 6)]          0
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 30)           210         deep_input[0][0]
# __________________________________________________________________________________________________
# wide_input (InputLayer)         [(None, 5)]          0
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 30)           930         dense_3[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 35)           0           wide_input[0][0]
#                                                                  dense_4[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 1)            36          concatenate_1[0][0]
# ==================================================================================================
# Total params: 1,176
# Trainable params: 1,176
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Train on 12384 samples, validate on 3096 samples
# Epoch 1/20
# 12384/12384 [==============================] - 0s 38us/sample - loss: 2.4249 - val_loss: 0.9944
# Epoch 2/20
# 12384/12384 [==============================] - 0s 28us/sample - loss: 0.8001 - val_loss: 0.7387
# Epoch 3/20
# 12384/12384 [==============================] - 0s 27us/sample - loss: 0.6500 - val_loss: 0.6536
# Epoch 4/20
# 12384/12384 [==============================] - 0s 27us/sample - loss: 0.5949 - val_loss: 0.6076
# Epoch 5/20
# 12384/12384 [==============================] - 0s 26us/sample - loss: 0.5588 - val_loss: 0.5762
# Epoch 6/20
# 12384/12384 [==============================] - 0s 25us/sample - loss: 0.5331 - val_loss: 0.5535
# Epoch 7/20
# 12384/12384 [==============================] - 0s 26us/sample - loss: 0.5135 - val_loss: 0.5357
# Epoch 8/20
# 12384/12384 [==============================] - 0s 25us/sample - loss: 0.4985 - val_loss: 0.5214
# Epoch 9/20
# 12384/12384 [==============================] - 0s 25us/sample - loss: 0.4860 - val_loss: 0.5114
# Epoch 10/20
# 12384/12384 [==============================] - 0s 25us/sample - loss: 0.4761 - val_loss: 0.4999
# Epoch 11/20
# 12384/12384 [==============================] - 0s 26us/sample - loss: 0.4674 - val_loss: 0.4915
# Epoch 12/20
# 12384/12384 [==============================] - 0s 25us/sample - loss: 0.4585 - val_loss: 0.4836
# Epoch 13/20
# 12384/12384 [==============================] - 0s 26us/sample - loss: 0.4521 - val_loss: 0.4777
# Epoch 14/20
# 12384/12384 [==============================] - 0s 26us/sample - loss: 0.4459 - val_loss: 0.4725
# Epoch 15/20
# 12384/12384 [==============================] - 0s 27us/sample - loss: 0.4402 - val_loss: 0.4670
# Epoch 16/20
# 12384/12384 [==============================] - 0s 26us/sample - loss: 0.4365 - val_loss: 0.4642
# Epoch 17/20
# 12384/12384 [==============================] - 0s 26us/sample - loss: 0.4326 - val_loss: 0.4591
# Epoch 18/20
# 12384/12384 [==============================] - 0s 25us/sample - loss: 0.4290 - val_loss: 0.4561
# Epoch 19/20
# 12384/12384 [==============================] - 0s 26us/sample - loss: 0.4261 - val_loss: 0.4550
# Epoch 20/20
# 12384/12384 [==============================] - 0s 25us/sample - loss: 0.4234 - val_loss: 0.4506
# 5160/5160 [==============================] - 0s 13us/sample - loss: 0.4382
# [4.259 2.563 2.595] [[2.6523368]
#  [2.7540686]
#  [2.6825058]]

# %% [markdown]
# ### Handling multiple outputs; In this case to add an auxillary output for regularization
# #### Each output needs its own loss function. So, we pass a list of losses
# #### By default, keras will compute all these losses and simply add them up to get the final loss used for training. We care musch more about the main output then about the aux output. So, we give more weight to output's loss than aux output's loss

# %%
input_A = keras.layers.Input(shape=[5], name="wide_input")
input_B = keras.layers.Input(shape=[6], name="deep_input")
hidden = keras.layers.Dense(30, activation="relu")(input_B)
hidden = keras.layers.Dense(30, activation="relu")(hidden)
concat = keras.layers.Concatenate()([input_A, hidden])
output = keras.layers.Dense(1, name="main_output")(concat)
aux_output = keras.layers.Dense(1, name="aux_output")(hidden)
model = keras.Model(inputs=[input_A, input_B], outputs=[output, aux_output])

model.compile(loss=["mse", "mse"], loss_weights=[0.9, 0.1], optimizer="sgd")
model.summary()

history = model.fit((X_train[:, :5], X_train[:, 2:]), (y_train, y_train), epochs=20, validation_split=0.2,
                   callbacks=[keras.callbacks.TensorBoard(get_run_logdir())])

mse_test = model.evaluate((X_test[:, :5], X_test[:, 2:]), (y_test, y_test))

X_new = X_test[:3] #pretend these are new instances to do some testing
y_pred = model.predict((X_new[:, :5], X_new[:, 2:]))
print(y_test[:3], y_pred)
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# deep_input (InputLayer)         [(None, 6)]          0
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 30)           210         deep_input[0][0]
# __________________________________________________________________________________________________
# wide_input (InputLayer)         [(None, 5)]          0
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 30)           930         dense_6[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 35)           0           wide_input[0][0]
#                                                                  dense_7[0][0]
# __________________________________________________________________________________________________
# main_output (Dense)             (None, 1)            36          concatenate_2[0][0]
# __________________________________________________________________________________________________
# aux_output (Dense)              (None, 1)            31          dense_7[0][0]
# ==================================================================================================
# Total params: 1,207
# Trainable params: 1,207
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Train on 12384 samples, validate on 3096 samples
# Epoch 1/20
# 12384/12384 [==============================] - 1s 51us/sample - loss: 2.6499 - main_output_loss: 2.4117 - aux_output_loss: 4.7936 - val_loss: 1.3721 - val_main_output_loss: 1.1067 - val_aux_output_loss: 3.7610
# Epoch 2/20
# 12384/12384 [==============================] - 0s 31us/sample - loss: 1.0847 - main_output_loss: 0.8723 - aux_output_loss: 2.9962 - val_loss: 0.9529 - val_main_output_loss: 0.7829 - val_aux_output_loss: 2.4827
# Epoch 3/20
# 12384/12384 [==============================] - 0s 29us/sample - loss: 0.8361 - main_output_loss: 0.6922 - aux_output_loss: 2.1316 - val_loss: 0.8081 - val_main_output_loss: 0.6854 - val_aux_output_loss: 1.9127
# Epoch 4/20
# 12384/12384 [==============================] - 0s 32us/sample - loss: 0.7396 - main_output_loss: 0.6294 - aux_output_loss: 1.7314 - val_loss: 0.7369 - val_main_output_loss: 0.6387 - val_aux_output_loss: 1.6203
# Epoch 5/20
# 12384/12384 [==============================] - 0s 29us/sample - loss: 0.6840 - main_output_loss: 0.5934 - aux_output_loss: 1.4998 - val_loss: 0.6909 - val_main_output_loss: 0.6076 - val_aux_output_loss: 1.4409
# Epoch 6/20
# 12384/12384 [==============================] - 0s 29us/sample - loss: 0.6458 - main_output_loss: 0.5678 - aux_output_loss: 1.3479 - val_loss: 0.6581 - val_main_output_loss: 0.5840 - val_aux_output_loss: 1.3247
# Epoch 7/20
# 12384/12384 [==============================] - 0s 28us/sample - loss: 0.6166 - main_output_loss: 0.5471 - aux_output_loss: 1.2421 - val_loss: 0.6329 - val_main_output_loss: 0.5646 - val_aux_output_loss: 1.2479
# Epoch 8/20
# 12384/12384 [==============================] - 0s 30us/sample - loss: 0.5922 - main_output_loss: 0.5284 - aux_output_loss: 1.1664 - val_loss: 0.6113 - val_main_output_loss: 0.5472 - val_aux_output_loss: 1.1883
